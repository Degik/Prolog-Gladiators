# %%
import gym
import minihack
import numpy as np
import matplotlib.pyplot as plt
import IPython.display as display
import utils
import algorithms as algo

# %%
env = gym.make("MiniHack-Room-Random-15x15-v0", observation_keys=("chars", "pixel"))
state = env.reset()
env.render()
plt.imshow(state["pixel"][25:325, 490:760])
game_map = state["chars"]
game = state["pixel"]
# Out:
# Hello Agent, welcome to NetHack!  You are a chaotic male human Rogue.
#
#
#
#                                 ...............
#                                 ...............
#                                 ...............
#                                 ...............
#                                 ...............
#                                 ...............
#                                 ...............
#                                 ...............
#                                 ...............
#                                 ...............
#                                 ...............
#                                 ......>........
#                                 ...............
#                                 ...............
#                                 ..............@
#
#
#
# Agent the Footpad              St:18 Dx:18 Co:11 In:8 Wi:12 Ch:8 Chaotic S:0
# Dlvl:1 $:0 HP:12(12) Pw:2(2) AC:7 Xp:1/0

# %%
start = utils.get_player_location(game_map)
target = utils.get_target_location(game_map)
print(start)
print(target)
# Out:
# (17, 46)
# (14, 38)

# %%
path = algo.bfs(game_map, start, target)
print(path)
# Out:
# Target found!
# [(17, 46), (17, 45), (17, 44), (17, 43), (17, 42), (17, 41), (17, 40), (17, 39), (17, 38), (16, 38), (15, 38), (14, 38)]

# %%
actions = utils.actions_from_path(start, path[1:])
print(actions)
# Out:
# [3, 3, 3, 3, 3, 3, 3, 3, 0, 0, 0]

# %%
image = plt.imshow(game[25:325, 490:760])
for action in actions:
    s, _, _, _ = env.step(action)
    display.display(plt.gcf())
    display.clear_output(wait=True)
    image.set_data(s["pixel"][25:325, 490:760])
